# %% [markdown]
# # Wide to Long Transformation Lab

# %% [markdown]
# ## intro and objectives

# %% [markdown]
# ### 0. Load required libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. Let's load some data

# %% [markdown]
# ### 1.1. COVID-19.

# %% [markdown]
# ### We load the Wide Format versions of the COVID-19 Dataset. Refer to Lab 1 for more information

# %%
covingCasesWideFormatDataFrame = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/Python4DS102/main/data/covingCasesWideFormatDataFrame.csv')

# %%
covingDeathsWideFormatDataFrame = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/Python4DS102/main/data/covingDeathsWideFormatDataFrame.csv')

# %%
covingCasesWideFormatDataFrame.head()
# Out:
#       dateRep  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 0  01/01/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 1  01/02/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 2  01/03/2020          0.0      NaN      2.0      NaN     NaN       NaN
# 3  01/04/2020         25.0     20.0    132.0      6.0     0.0       0.0
# 4  01/05/2020        222.0      7.0    158.0      2.0     0.0       0.0
#
#    Antigua_and_Barbuda  Argentina  Armenia  ...  United_States_Virgin_Islands  \
# 0                  NaN        NaN      0.0  ...                           NaN
# 1                  NaN        NaN      0.0  ...                           NaN
# 2                  NaN        NaN      1.0  ...                           NaN
# 3                  0.0        0.0     39.0  ...                           0.0
# 4                  0.0      143.0     82.0  ...                           0.0
#
# ...

# %%
covingDeathsWideFormatDataFrame.head()
# Out:
#       dateRep  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 0  01/01/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 1  01/02/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 2  01/03/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 3  01/04/2020          0.0      3.0      9.0      4.0     0.0       0.0
# 4  01/05/2020          4.0      0.0      6.0      0.0     0.0       0.0
#
#    Antigua_and_Barbuda  Argentina  Armenia  ...  United_States_Virgin_Islands  \
# 0                  NaN        NaN      0.0  ...                           NaN
# 1                  NaN        NaN      0.0  ...                           NaN
# 2                  NaN        NaN      0.0  ...                           NaN
# 3                  0.0        0.0      0.0  ...                           0.0
# 4                  0.0        4.0      1.0  ...                           0.0
#
# ...

# %% [markdown]
# ### The previous COVID-19 DataFrames are presented in the so-called wide format.
# ### Wide Format DataFrames are quite common in econometric contexts as it is the usual format to represent panel data
#
# <img src="https://github.com/thousandoaks/Python4DS102/blob/main/images/wideformatdataframe.png?raw=1">

# %% [markdown]
# ## 2 Wide to Long transformation. MELT Operations
# #### Pandas provides the method "melt" to tranform DataFrames from long form to wide equivalent.

# %% [markdown]
# ### 2.1. Let's melt the cases DataFrame
#
# <img src="https://github.com/thousandoaks/Python4DS102/blob/main/images/meltoperation.png?raw=1">

# %%
covingCasesWideFormatDataFrame
# Out:
#         dateRep  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 0    01/01/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 1    01/02/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 2    01/03/2020          0.0      NaN      2.0      NaN     NaN       NaN
# 3    01/04/2020         25.0     20.0    132.0      6.0     0.0       0.0
# 4    01/05/2020        222.0      7.0    158.0      2.0     0.0       0.0
# ..          ...          ...      ...      ...      ...     ...       ...
# 259  31/03/2020         27.0     11.0     73.0     36.0     0.0       0.0
# 260  31/05/2020        866.0     23.0    133.0      0.0     7.0       0.0
# 261  31/07/2020         71.0     92.0    602.0      4.0    78.0       0.0
# 262  31/08/2020         19.0    101.0    364.0      0.0    73.0       0.0
# 263  31/12/2019          0.0      NaN      0.0      NaN     NaN       NaN
#
#      Antigua_and_Barbuda  Argentina  Armenia  ...  \
# ...

# %%
covingCasesLongFormatDataFrame=covingCasesWideFormatDataFrame.melt(id_vars=["dateRep"],var_name='Country', value_name='cases')

# %%
covingCasesLongFormatDataFrame
# Out:
#           dateRep      Country  cases
# 0      01/01/2020  Afghanistan    0.0
# 1      01/02/2020  Afghanistan    0.0
# 2      01/03/2020  Afghanistan    0.0
# 3      01/04/2020  Afghanistan   25.0
# 4      01/05/2020  Afghanistan  222.0
# ...           ...          ...    ...
# 55435  31/03/2020     Zimbabwe    0.0
# 55436  31/05/2020     Zimbabwe   14.0
# 55437  31/07/2020     Zimbabwe  213.0
# 55438  31/08/2020     Zimbabwe    6.0
# 55439  31/12/2019     Zimbabwe    NaN
#
# [55440 rows x 3 columns]

# %% [markdown]
# ### 2.2. Let's melt the deaths DataFrame
#
# <img src="https://github.com/thousandoaks/Python4DS102/blob/main/images/meltoperation2.png?raw=1">

# %%
covingDeathsWideFormatDataFrame
# Out:
#         dateRep  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 0    01/01/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 1    01/02/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 2    01/03/2020          0.0      NaN      0.0      NaN     NaN       NaN
# 3    01/04/2020          0.0      3.0      9.0      4.0     0.0       0.0
# 4    01/05/2020          4.0      0.0      6.0      0.0     0.0       0.0
# ..          ...          ...      ...      ...      ...     ...       ...
# 259  31/03/2020          0.0      2.0      4.0      2.0     0.0       0.0
# 260  31/05/2020          3.0      0.0      8.0      0.0     0.0       0.0
# 261  31/07/2020          0.0      4.0     14.0      0.0     1.0       0.0
# 262  31/08/2020          0.0      5.0     10.0      0.0     0.0       0.0
# 263  31/12/2019          0.0      NaN      0.0      NaN     NaN       NaN
#
#      Antigua_and_Barbuda  Argentina  Armenia  ...  \
# ...

# %%
covingDeathsLongFormatDataFrame=covingDeathsWideFormatDataFrame.melt(id_vars=["dateRep"],var_name='Country', value_name='deaths')

# %%
covingDeathsLongFormatDataFrame
# Out:
#           dateRep      Country  deaths
# 0      01/01/2020  Afghanistan     0.0
# 1      01/02/2020  Afghanistan     0.0
# 2      01/03/2020  Afghanistan     0.0
# 3      01/04/2020  Afghanistan     0.0
# 4      01/05/2020  Afghanistan     4.0
# ...           ...          ...     ...
# 55435  31/03/2020     Zimbabwe     0.0
# 55436  31/05/2020     Zimbabwe     0.0
# 55437  31/07/2020     Zimbabwe    12.0
# 55438  31/08/2020     Zimbabwe     0.0
# 55439  31/12/2019     Zimbabwe     NaN
#
# [55440 rows x 3 columns]

# %% [markdown]
# ### 2.3. Let's combine both DataFrames into a single one

# %% [markdown]
# #### We join the two DataFrames using dateRep and Country as keys

# %%
covingCasesAndDeathsLongFormatDataFrame=pd.merge(covingCasesLongFormatDataFrame,covingDeathsLongFormatDataFrame,on=['dateRep','Country'])

# %%
covingCasesAndDeathsLongFormatDataFrame
# Out:
#           dateRep      Country  cases  deaths
# 0      01/01/2020  Afghanistan    0.0     0.0
# 1      01/02/2020  Afghanistan    0.0     0.0
# 2      01/03/2020  Afghanistan    0.0     0.0
# 3      01/04/2020  Afghanistan   25.0     0.0
# 4      01/05/2020  Afghanistan  222.0     4.0
# ...           ...          ...    ...     ...
# 55435  31/03/2020     Zimbabwe    0.0     0.0
# 55436  31/05/2020     Zimbabwe   14.0     0.0
# 55437  31/07/2020     Zimbabwe  213.0    12.0
# 55438  31/08/2020     Zimbabwe    6.0     0.0
# 55439  31/12/2019     Zimbabwe    NaN     NaN
#
# [55440 rows x 4 columns]

# %% [markdown]
# #### If we need to transform into a 100% Long Form DataFrame:

# %%
covingCasesAndDeathsLongFormatDataFrameAlternative=covingCasesAndDeathsLongFormatDataFrame.melt(id_vars=["dateRep",'Country'])

# %%
covingCasesAndDeathsLongFormatDataFrameAlternative
# Out:
#            dateRep      Country variable  value
# 0       01/01/2020  Afghanistan    cases    0.0
# 1       01/02/2020  Afghanistan    cases    0.0
# 2       01/03/2020  Afghanistan    cases    0.0
# 3       01/04/2020  Afghanistan    cases   25.0
# 4       01/05/2020  Afghanistan    cases  222.0
# ...            ...          ...      ...    ...
# 110875  31/03/2020     Zimbabwe   deaths    0.0
# 110876  31/05/2020     Zimbabwe   deaths    0.0
# 110877  31/07/2020     Zimbabwe   deaths   12.0
# 110878  31/08/2020     Zimbabwe   deaths    0.0
# 110879  31/12/2019     Zimbabwe   deaths    NaN
#
# [110880 rows x 4 columns]
